# %%
import pandas as pd

# %%
df = pd.read_csv('Academic_Eficiency.csv', sep=';')
# Out:
# C:\Users\vinic\AppData\Local\Temp\ipykernel_6892\2796006804.py:1: DtypeWarning: Columns (19) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('Academic_Eficiency.csv', sep=';')

# %%
evaded_df = df[df['Categoria da Situação']=='Evadidos']

# %%
evaded_df.to_csv('evasao.csv')

# %%
# Out:
# array(['Evadidos', 'Concluintes', 'Em curso'], dtype=object)

# %%
evaded_df.columns
# Out:
# Index(['Carga Horaria', 'Carga Horaria Mínima', 'Categoria da Situação',
#        'Cod Unidade', 'Cor / Raça', 'Código da Matricula',
#        'Código da Unidade de Ensino - SISTEC', 'Código do Ciclo Matricula',
#        'Código do Município com DV', 'Data de Fim Previsto do Ciclo',
#        'Data de Inicio do Ciclo', 'Data de Ocorrencia da Matricula',
#        'Eixo Tecnológico', 'Faixa Etária', 'Fator Esforço Curso',
#        'Fonte de Financiamento', 'Idade', 'Instituição', 'Matrículas Atendida',
#        'Matrículas Equivalentes', 'Modalidade de Ensino', 'Município',
#        'Mês De Ocorrência da Situação', 'Nome de Curso', 'Número de registros',
#        'Região', 'Renda Familiar', 'Sexo', 'Situação de Matrícula',
#        'Subeixo Tecnológico', 'Tipo de Curso', 'Tipo de Oferta',
#        'Total de Inscritos', 'Turno', 'UF', 'Unidade de Ensino',
#        'Vagas Extraordinárias AC', 'Vagas Extraordinárias l1',
#        'Vagas Extraordinárias l10', 'Vagas Extraordinárias l13',
# ...

# %%
from datetime import datetime

dates = list(df['Mês De Ocorrência da Situação'])

# %%
sorted(dates, key=lambda x: datetime.strptime(x, '%d/%m/%Y'))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [39], line 1
# ----> 1 sorted(dates, key=lambda x: datetime.strptime(x, '%d/%m/%Y'))
#
# Cell In [39], line 1, in <lambda>(x)
# ----> 1 sorted(dates, key=lambda x: datetime.strptime(x, '%d/%m/%Y'))
#
# TypeError: strptime() argument 1 must be str, not float

# %%
for i in dates:
    a = type(i)
    if a != str:
        print(a)
        print(i)
# Out:
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# ...
